# %% [markdown]
# <a href="https://colab.research.google.com/github/dassatabdi24/Geo-Machine-Learning/blob/master/gmaptaxi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googlemaps

# %%
# !pip install datetime

# %%
# !pip install gmaps

# %%
import os
import gmaps
import gmaps.datasets
import googlemaps
from datetime import datetime
from googlemaps import convert
from googlemaps.client import Client
from googlemaps import exceptions
import IPython
from ipywidgets.embed import embed_minimal_html

# %%
gmaps.configure(api_key ='AIzaSyCqrpUmXSmo5er-h_GIa4b_dBYM43aovEo')
api_key = 'AIzaSyCqrpUmXSmo5er-h_GIa4b_dBYM43aovEo'

# %%
# Get the dataset
taxi_df = gmaps.datasets.load_dataset_as_df("taxi_rides")
#Get the locations from the data set
locations = taxi_df[['latitude', 'longitude']]
#Set up your map
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations))

# %%
taxi_df.head()
# Out:
#     latitude   longitude
# 0  37.782551 -122.445368
# 1  37.782745 -122.444586
# 2  37.782842 -122.443688
# 3  37.782919 -122.442815
# 4  37.782992 -122.442112

# %%
#no output 
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#output is saved as html
embed_minimal_html('export.html', views=[fig])
IPython.display.HTML(filename='export.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>IPyWidget export</title>
# </head>
# <body>
#
#
# <!-- Load require.js. Delete this if your page already loads require.js -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>
# <script src="https://unpkg.com/@jupyter-widgets/html-manager@^0.18.0/dist/embed-amd.js" crossorigin="anonymous"></script>
#
# <script type="application/vnd.jupyter.widget-state+json">
# {
#   "version_major": 2,
#   "version_minor": 0,
#   "state": {
#     "4a431aae734a490393c9e6b6c4bea17e": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "100%",
#         "width": "100%"
#       }
#     },
#     "845bf8a0868041df96daf37ea9284040": {
#       "model_name": "PlainmapModel",
# ...
