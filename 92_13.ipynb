# %%
import rasterio.mask
import os
from matplotlib import pyplot

src=rasterio.open('E:\Thesis\Data\cropped\F101992.v4b_web.stable_lights.avg_vis.tif')
pyplot.imshow(src.read(1), cmap='pink')
pyplot.xlim(0,200)
pyplot.ylim(150,0)
pyplot.show()

src=rasterio.open('E:\Thesis\Data\cropped\F182013.v4c_web.stable_lights.avg_vis.tif')
pyplot.imshow(src.read(1), cmap='pink')
pyplot.xlim(0,200)
pyplot.ylim(150,0)
pyplot.show()
