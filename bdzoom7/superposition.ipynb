# %%
import gdal
import sys
import os
import path

src_path = 'J:\\CSE books\\4-1\\Thesis\\out\\BGD_\\latest\\SVDNB_npp_20190401-20190430_75N060E_vcmslcfg_v10_c201905191000.avg_rade9h.tif'
ds = gdal.Open(src_path)

gt = ds.GetGeoTransform()

width_px = ds.RasterXSize
height_px = ds.RasterYSize
ulx, xres, xskew, uly, yskew, yres  = ds.GetGeoTransform()
lrx = ulx + (ds.RasterXSize * xres)
lry = uly + (ds.RasterYSize * yres)

# %%
height_px
# Out:
# 1415

# %%
width_px
# Out:
# 1120

# %%
center_x = ((ulx+lrx)/2)
center_y = ((uly+lry)/2)

# %%
print(ulx,uly,lrx,lry)
# Out:
# 88.01041689075001 26.635416279749997 92.67708359475 20.739582899249996

# %%
print(center_x)
print(center_y)
# Out:
# 90.34375024275
# 23.687499589499996

# %%
# Python program to get a google map  
# image of specified location using  
# Google Static Maps API 
# https://maps.googleapis.com/maps/api/staticmap?center
# =Berkeley,CA&zoom=14&size=400x400&key=AIzaSyBDw_c-SgjTS0vtLvDU2mcO2wwfsK9Ourg
# importing required modules 
import requests 
  
# Enter your api key here 
api_key = "AIzaSyBDw_c-SgjTS0vtLvDU2mcO2wwfsK9Ourg"
  
# url variable store url 
url = "https://maps.googleapis.com/maps/api/staticmap?"
  
# center defines the center of the map, 
# equidistant from all edges of the map. 
#center = center_y, center_x 
center = "23.687499589499996, 90.34375024275"
  
# zoom defines the zoom 
# level of the map 
zoom = 7

  
# get method of requests module 
# return response object
s = url + "center=" + center + "&scale=4" + "&zoom=" + str(zoom) + "&size=2040x2040&key=" + api_key
r = requests.get(s) 
print(s)
# wb mode is stand for write binary mode 
f = open('gmap1', 'wb') 
  
# r.content gives content, 
# in this case gives image 
f.write(r.content) 
  
# close method of file object 
# save and close the file 
f.close()
# Out:
# https://maps.googleapis.com/maps/api/staticmap?center=23.687499589499996, 90.34375024275&scale=4&zoom=7&size=2040x2040&key=AIzaSyBDw_c-SgjTS0vtLvDU2mcO2wwfsK9Ourg

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np
# %matplotlib inline
import gdal
import rasterio
from rasterio.merge import merge
from rasterio.plot import show
import glob
import os

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('gmap1')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
src2 = rasterio.open("J:\\CSE books\\4-1\\Thesis\\data\\bdgmapzoom7.tif")
plt.imshow(src2.read(1), cmap='terrain')
plt.figure(figsize = (6,6))
plt.show()

# %%
src1 = rasterio.open('J:\\CSE books\\4-1\\Thesis\\out\\BGD_\\latest\\SVDNB_npp_20190401-20190430_75N060E_vcmslcfg_v10_c201905191000.avg_rade9h.tif')
plt.imshow(src1.read(1), clim=(0, 75), cmap='prism')
plt.figure(figsize = (7,7))
plt.show()

# %%
import fiona
import rasterio
import rasterio.plot
import matplotlib as mpl
import matplotlib.pyplot as plt
from descartes import PolygonPatch

src = rasterio.open("J:\\CSE books\\4-1\\Thesis\\data\\bdgmapzoom7.tif")

import matplotlib.image as mpimg
#plt.imshow(src.read(1), cmap='pink')
#plt.xlim(0,200)
#plt.ylim(200,0)
#plt.grid(color='w', linestyle='-', linewidth=2)
plt.figure(figsize = (10,10))
src2 = rasterio.open("J:\\CSE books\\4-1\\Thesis\\out\\BGD_\\latest\\SVDNB_npp_20190401-20190430_75N060E_vcmslcfg_v10_c201905191000.avg_rade9h.tif")
plt.imshow(src.read(1), cmap='terrain')
plt.imshow(src2.read(1), clim=(0, 75), cmap='prism', alpha = 0.5)
plt.show()
