# %% [markdown]
# <a href="https://colab.research.google.com/github/dassatabdi24/Geo-Machine-Learning/blob/master/Data_Layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Layers**

# %%
# !pip install gmaps
# Out:
# ...
#      |████████████████████████████████| 1.1MB 9.3MB/s
# ...
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076096 sha256=843dfb850bfdfd6752f8724a957ecfca7811000b46f4b4dbfff6d5ec03730489
#   Stored in directory: /root/.cache/pip/wheels/33/eb/41/5302168c36fc8ce8f48143bb58fde1015d5bc0c62bc3ddbb38
# Successfully built gmaps
# ...

# %%
import gmaps
#billing account
gmaps.configure(api_key="AIzaSyBDw_c-SgjTS0vtLvDU2mcO2wwfsK9Ourg")

# Map centered on Bangladesh
fig2 = gmaps.figure(center=(23.8540299172, 90.415498338), zoom_level=12)
#adding transit layer
fig2.add_layer(gmaps.transit_layer())

# %%
from ipywidgets.embed import embed_minimal_html
embed_minimal_html('export.html', views=[fig2])
import IPython
IPython.display.HTML(filename='export.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>IPyWidget export</title>
# </head>
# <body>
#
#
# <!-- Load require.js. Delete this if your page already loads require.js -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>
# <script src="https://unpkg.com/@jupyter-widgets/html-manager@^0.18.0/dist/embed-amd.js" crossorigin="anonymous"></script>
#
# <script type="application/vnd.jupyter.widget-state+json">
# {
#   "version_major": 2,
#   "version_minor": 0,
#   "state": {
#     "e6f0bbbc97674dd7aec65c5993322795": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "100%",
#         "width": "100%"
#       }
#     },
#     "9c4ba8b21ba04279826feced5196d348": {
#       "model_name": "PlainmapModel",
# ...

# %%
import gmaps
#developer account
gmaps.configure(api_key='AIzaSyCqrpUmXSmo5er-h_GIa4b_dBYM43aovEo')

# Map centered on Bangladesh
fig = gmaps.figure(center=(23.8540299172, 90.415498338), zoom_level=12)
fig.add_layer(gmaps.transit_layer())

# %%
from ipywidgets.embed import embed_minimal_html
embed_minimal_html('export.html', views=[fig])
import IPython
IPython.display.HTML(filename='export.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>IPyWidget export</title>
# </head>
# <body>
#
#
# <!-- Load require.js. Delete this if your page already loads require.js -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>
# <script src="https://unpkg.com/@jupyter-widgets/html-manager@^0.18.0/dist/embed-amd.js" crossorigin="anonymous"></script>
#
# <script type="application/vnd.jupyter.widget-state+json">
# {
#   "version_major": 2,
#   "version_minor": 0,
#   "state": {
#     "e6f0bbbc97674dd7aec65c5993322795": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "100%",
#         "width": "100%"
#       }
#     },
#     "9c4ba8b21ba04279826feced5196d348": {
#       "model_name": "PlainmapModel",
# ...
