# %%
import requests 
  
# Enter your api key here 
api_key = "AIzaSyBDw_c-SgjTS0vtLvDU2mcO2wwfsK9Ourg"
  
# url variable store url 
url = "https://maps.googleapis.com/maps/api/staticmap?"
  
# center defines the center of the map, 
# equidistant from all edges of the map.  
center = "Rangpur"
  
# zoom defines the zoom 
# level of the map 
zoom = 7
  
# get method of requests module 
# return response object
s = url + "center=" + center + "&zoom=" + str(zoom) + "&size=200x200&key=" + api_key
r = requests.get(s) 
print(s)
# wb mode is stand for write binary mode 
f = open('E:/Thesis/Data/a.txt', 'wb') 
  
# r.content gives content, 
# in this case gives image 
f.write(r.content) 
  
# close method of file object 
# save and close the file 
f.close() 
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('E:/Thesis/Data/a.txt')
imgplot = plt.imshow(img)
#plt.xlim(0,50)
#plt.ylim(50,0)
plt.show()
# Out:
# https://maps.googleapis.com/maps/api/staticmap?center=Rangpur&zoom=7&size=200x200&key=AIzaSyBDw_c-SgjTS0vtLvDU2mcO2wwfsK9Ourg
# Populating the interactive namespace from numpy and matplotlib

# %%
import fiona
import rasterio
import rasterio.plot
import matplotlib as mpl
import matplotlib.pyplot as plt
from descartes import PolygonPatch

src = rasterio.open("E:/Thesis/Data/cropped/F182011.v4c_web.stable_lights.avg_vis.tif")

with fiona.open("E:/Thesis/Data/bangladesh-latest-free/gis_osm_transport_free_1.shp", "r") as shapefile:
    features = [feature["geometry"] for feature in shapefile]

import matplotlib.image as mpimg
#plt.imshow(src.read(1), cmap='pink')
#plt.xlim(0,200)
#plt.ylim(200,0)
#plt.grid(color='w', linestyle='-', linewidth=2)

img2=mpimg.imread('E:/Thesis/Data/a.txt')


plt.figure(figsize = (10,10))
plt.imshow(src.read(1), cmap='pink')
plt.xlim(0,200)
plt.ylim(200,0)
plt.imshow(img2, alpha=0.5)

plt.show()

# %%
import gmaps.geojson_geometries
import gmaps
gmaps.configure("AIzaSyBDw_c-SgjTS0vtLvDU2mcO2wwfsK9Ourg")
countries_geojson=gmaps.geojson_geometries.load_geometry('countries')

# %%
gini_layer=gmaps.geojson_layer(countries_geojson)
print(countries_geojson['features'][0])
# Out:
# {'geometry': {'type': 'Polygon', 'coordinates': [[[71.04980228700009, 38.40866445000009], [71.3343843990001, 38.28066192700001], [71.36451176000008, 38.206816305000046], [71.25578454600003, 37.94988108300004], [71.34115401300005, 37.89329539000008], [71.50119592300013, 37.94621205700014], [71.59772749900003, 37.898359681000045], [71.59028609300003, 37.815729065000085], [71.49716516100011, 37.56654530900008], [71.48703658000005, 37.26705454600011], [71.45013960700004, 37.216670024000024], [71.43112268100009, 37.06698923700014], [71.46305871600009, 36.94808176700013], [71.55287235600008, 36.76959137000006], [71.6110600180001, 36.704840800000056], [71.74851932800004, 36.67864084900012], [71.83657596900014, 36.699156392000106], [72.12668746000008, 36.87273752900006], [72.25980594900005, 36.96730540000007], [72.40594689900013, 37.00766469300004], [72.65771447800006, 37.02882619200008], [72.7609639900001, 37.18749867800008], [72.99557499200006, 37.3093000290001], [73.06750858600009, 37.315
# ...

# %%
gmaps.geojson_geometries.list_geometries()
gmaps.geojson_geometries.geometry_metadata('india-states')
countries_geojson=gmaps.geojson_geometries.load_geometry('india-states')
print(countries_geojson['features'])
# Out:
# [{'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[93.84805297851591, 7.240280151367472], [93.84249877929716, 7.228610992431584], [93.85138702392578, 7.213890075683594], [93.85916900634783, 7.217222213745288], [93.87027740478521, 7.215834140777588], [93.88363647460943, 7.188451766967773], [93.87999725341797, 7.174723148345947], [93.8878936767581, 7.15114688873291], [93.88471984863298, 7.134780883789119], [93.88569641113298, 7.125827789306641], [93.89138793945312, 7.121110916137752], [93.8855590820313, 7.105001926422119], [93.88777923584001, 7.086390018463305], [93.89314270019548, 7.078775882720947], [93.901664733887, 7.077498912811393], [93.90556335449224, 7.062780857086295], [93.91666412353521, 7.048404216766471], [93.91249847412138, 7.041110992431584], [93.92055511474604, 7.02333307266241], [93.9272766113283, 7.027291774749756], [93.93653106689482, 7.013331890106315], [93.94548034667974, 7.009409904480094], [93.9476623535158, 6.998178958892879], [93.942916
# ...
