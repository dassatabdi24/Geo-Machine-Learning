# %%
import gdal
import sys
import os
import path

src_path = 'J:\\CSE books\\4-1\\Thesis\\out\\BGD_\\latest88_24.tif'
ds = gdal.Open(src_path)

gt = ds.GetGeoTransform()

width_px = ds.RasterXSize
height_px = ds.RasterYSize
ulx, xres, xskew, uly, yskew, yres  = ds.GetGeoTransform()
lrx = ulx + (ds.RasterXSize * xres)
lry = uly + (ds.RasterYSize * yres)

# %%
center_x = (ulx+lrx)/2
center_y = (uly+lry)/2

# %%
print(center_x)
print(center_y)
# Out:
# 88.5
# 24.5

# %%
# Python program to get a google map  
# image of specified location using  
# Google Static Maps API 
# https://maps.googleapis.com/maps/api/staticmap?center
# =Berkeley,CA&zoom=14&size=400x400&key=AIzaSyBDw_c-SgjTS0vtLvDU2mcO2wwfsK9Ourg
# importing required modules 
import requests 
  
# Enter your api key here 
api_key = "AIzaSyBDw_c-SgjTS0vtLvDU2mcO2wwfsK9Ourg"
  
# url variable store url 
url = "https://maps.googleapis.com/maps/api/staticmap?"
  
# center defines the center of the map, 
# equidistant from all edges of the map. 
#center = center_y, center_x 
center = "24.5, 88.5"
  
# zoom defines the zoom 
# level of the map 
zoom = 12
  
# get method of requests module 
# return response object
s = url + "center=" + center + "&zoom=" + str(zoom) + "&size=240x240&key=" + api_key
r = requests.get(s) 
print(s)
# wb mode is stand for write binary mode 
f = open('gmap1', 'wb') 
  
# r.content gives content, 
# in this case gives image 
f.write(r.content) 
  
# close method of file object 
# save and close the file 
f.close()
# Out:
# https://maps.googleapis.com/maps/api/staticmap?center=24.5, 88.5&zoom=12&size=240x240&key=AIzaSyBDw_c-SgjTS0vtLvDU2mcO2wwfsK9Ourg

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np
# %matplotlib inline
import gdal
import rasterio
from rasterio.merge import merge
from rasterio.plot import show
import glob
import os

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('gmap1')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
src1 = rasterio.open('J:\\CSE books\\4-1\\Thesis\\out\\BGD_\\latest88_24.tif')
plt.imshow(src1.read(1), cmap='pink')
plt.show()

# %%
import fiona
import rasterio
import rasterio.plot
import matplotlib as mpl
import matplotlib.pyplot as plt
from descartes import PolygonPatch

src = rasterio.open("J:\\CSE books\\4-1\\Thesis\\out\\BGD_\\latest88_24.tif")


import matplotlib.image as mpimg
#plt.imshow(src.read(1), cmap='pink')
#plt.xlim(0,200)
#plt.ylim(200,0)
#plt.grid(color='w', linestyle='-', linewidth=2)

img=mpimg.imread('gmap1')


plt.figure(figsize = (10,10))
plt.imshow(src.read(1), cmap='pink')
plt.xlim(0,240)
plt.ylim(240,0)
plt.imshow(img, alpha=0.4)

plt.show()
